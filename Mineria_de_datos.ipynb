# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhcs-2003/Mineria_datos/blob/main/Mineria_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# La minería de datos es el uso del machine learning y el análisis estadístico para descubrir patrones y otra información valiosa a partir de grandes conjuntos de datos.
#
# Las técnicas de minería de datos que sustentan los análisis de datos se pueden implementar para dos propósitos principales. Pueden describir el conjunto de datos objetivo o pueden predecir resultados mediante el uso de algoritmos de machine learning.

# %% [markdown]
# #### Ciencia de datos

# %% [markdown]
# La ciencia de datos es un campo interdisciplinario que combina matemáticas, estadística, programación, inteligencia artificial y aprendizaje automático  para analizar grandes volúmenes de datos estructurados y no estructurados.
#
# Su objetivo principal es extraer información valiosa que permita tomar decisiones estratégicas y resolver problemas empresariales.

# %% [markdown]
# Help and Documentation in Python

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# IPython Magic Commands

# %%
# Esta función nos sirve para evaluar el desempeño de una expresión en cuanto a tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 68.3 µs ± 874 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# Con doble porcentaje podemos evaluar el desempeño en cuanto a tiempo de mas de una linea
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 78.8 µs ± 8.06 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# IPython and Shell Commands

# %%
# !ls
# Out:
# sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !echo "printing from the shell"
# Out:
# printing from the shell

# %%
contents = !pwd

# %%
print(contents)
# Out:
# ['/content']
